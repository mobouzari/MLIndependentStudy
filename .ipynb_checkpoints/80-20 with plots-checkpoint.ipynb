# %%
import numpy as np
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *
import sklearn
import pandas
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('contactid_08_01_18download.csv', encoding="utf-8")

# %%
df
# Out:
#        Subject.Id                 Contact.ID              cat  \
# 0            1003  a0000022d8b566-1485854260  No phone survey
# 1            1003     a0000022d8b566-4428755  No phone survey
# 2            1003   a0000022d8b566-682408058     Phone survey
# 3            1003   a0000022d8b5661085053215  No phone survey
# 4            1003   a0000022d8b5661306093745  No phone survey
# 5            1003   a0000022d8b5661374658182  No phone survey
# 6            1003   a0000022d8b5662119192337  No phone survey
# 7            1003   a0000022d8b5662120103081  No phone survey
# 8            1003    a0000022d8b566439263804  No phone survey
# 9            1003    a0000022d8b566691081474  No phone survey
# 10           1003    a0000022d8b566807313275  No phone survey
# 11           1003    a0000022d8b566915869100  No phone survey
# 12           1004  a0000022aa5cd6-1018899778  No phone survey
# 13           1004  a0000022aa5cd6-1043125280  No phone survey
# ...

# %%
dfclean = df.loc[df['close'].notnull()]

# %%
dfclean
# Out:
#        Subject.Id                 Contact.ID           cat svy_contact  \
# 2            1003   a0000022d8b566-682408058  Phone survey      Person
# 17           1004   a0000022aa5cd6-212065659  Phone survey      Person
# 24           1004   a0000022aa5cd61447330108  Phone survey      Person
# 28           1004   a0000022aa5cd62103159229  Phone survey      Person
# 33           1004    a0000022aa5cd6846559228  Phone survey      Person
# 36           1004  a0000022d95d9b-1043125280  Phone survey      Person
# 46           1004   a0000022d95d9b-879869607  Phone survey      Person
# 52           1004     a0000022d95d9b17610566  Phone survey      Person
# 61           1004    a0000022d95d9b846559228  Phone survey      Person
# 67           1005   a0000022aa2754-765626467  Phone survey      Person
# 68           1005    a0000022aa2754-97022750  Phone survey      Person
# 76           1005     a0000022aa275489361782  Phone survey      Person
# ...

# %%
dfclean.shape[0]
# Out:
# 2869

# %%
x = dfclean[['Total number of calls', 'Total duration of calls', 'Total incoming calls','Total outgoing calls','Proportion of incoming calls answered','Proportion of calls incoming','Duration of incoming calls','Duration of outgoing calls','Total number of night calls']].values #,'Total incoming calls','Total outgoing calls','Proportion of incoming calls answered','Proportion of calls incoming','Duration of incoming calls','Duration of outgoing calls','Total number of night calls']].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d4a9315d3bd> in <module>()
# ----> 1 x = dfclean[['Total number of calls', 'Total duration of calls', 'Total incoming calls','Total outgoing calls','Proportion of incoming calls answered','Proportion of calls incoming','Duration of incoming calls','Duration of outgoing calls','Total number of night calls']].values #,'Total incoming calls','Total outgoing calls','Proportion of incoming calls answered','Proportion of calls incoming','Duration of incoming calls','Duration of outgoing calls','Total number of night calls']].values
#
# NameError: name 'dfclean' is not defined

# %%
x = (dfclean.shape[0]) * .8

# %%
int(x)
# Out:
# 2295

# %%
xtrain = dfclean[:2295]

# %%
xtrain
# Out:
#        Subject.Id                 Contact.ID           cat svy_contact  \
# 2            1003   a0000022d8b566-682408058  Phone survey      Person
# 17           1004   a0000022aa5cd6-212065659  Phone survey      Person
# 24           1004   a0000022aa5cd61447330108  Phone survey      Person
# 28           1004   a0000022aa5cd62103159229  Phone survey      Person
# 33           1004    a0000022aa5cd6846559228  Phone survey      Person
# 36           1004  a0000022d95d9b-1043125280  Phone survey      Person
# 46           1004   a0000022d95d9b-879869607  Phone survey      Person
# 52           1004     a0000022d95d9b17610566  Phone survey      Person
# 61           1004    a0000022d95d9b846559228  Phone survey      Person
# 67           1005   a0000022aa2754-765626467  Phone survey      Person
# 68           1005    a0000022aa2754-97022750  Phone survey      Person
# 76           1005     a0000022aa275489361782  Phone survey      Person
# ...

# %%
xtest = dfclean[2296:]

# %%
xtest
# Out:
#        Subject.Id                 Contact.ID           cat svy_contact  \
# 13250        6005  a0000022d88633-2127882558  Phone survey      Person
# 13253        6005   a0000022d88633-325862347  Phone survey      Person
# 13267        6005   a0000022d88633-648755212  Phone survey      Person
# 13284        6005   a0000022d88633-928262169  Phone survey      Person
# 13292        6005   a0000022d886331140739601  Phone survey      Person
# 13309        6005   a0000022d886331420581866  Phone survey      Person
# 13313        6005   a0000022d886331450599911  Phone survey      Person
# 13316        6005    a0000022d88633153515508  Phone survey      Person
# 13317        6005   a0000022d886331539981973  Phone survey      Person
# 13320        6005   a0000022d886331620579599  Phone survey      Person
# 13323        6005   a0000022d886331640497990  Phone survey      Person
# 13336        6005   a0000022d886331947731002  Phone survey      Person
# ...

# %%
# ravel creates 1d array
y = dfclean[['close']].values.ravel()

# %%
ytrain = y[:2295]

# %%
ytrain
ytrain.shape
# Out:
# (2295,)

# %%
ytest = y[2296:]

# %%
ytest
ytest.shape
# Out:
# (573,)

# %%
xtrain.shape,ytrain.shape
# Out:
# ((2295, 36), (2295,))

# %%
#plt.ylim(0,800)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total number of calls'])
plt.xlabel('Close score')
plt.ylabel('Number of calls')
# Out:
# Text(0,0.5,'Number of calls')

# %%
#plt.ylim(0,300000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total duration of calls'])
plt.xlabel('Close score')
plt.ylabel('Call duration in seconds')
# Out:
# Text(0,0.5,'Call duration in seconds')

# %%
#plt.ylim(0,1000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total number of texts'])
plt.xlabel('Close score')
plt.ylabel('Number of texts')
# Out:
# Text(0,0.5,'Number of texts')

# %%
#plt.ylim(0,1000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total number of texts'])
plt.xlabel('Close score')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
#plt.ylim(0,1000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Max days between texts'])
plt.xlabel('Close score')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
#plt.ylim(0,1000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total number of missed calls'])
plt.xlabel('Close score')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
#plt.ylim(0,1000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total number of texts'])
plt.xlabel('Close score')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
#plt.ylim(0,1000)
plt.grid(True)
plt.scatter(ytrain, xtrain.loc[:,'Total number of texts'])
plt.xlabel('Close score')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
from sklearn.linear_model import SGDClassifier
classifierSGD = SGDClassifier(loss="hinge", penalty="l2")
classifierSGD.fit(xtrain,ytrain)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-418d22894a7b> in <module>()
#       1 from sklearn.linear_model import SGDClassifier
#       2 classifierSGD = SGDClassifier(loss="hinge", penalty="l2")
# ----> 3 classifierSGD.fit(xtrain,ytrain)
#
# D:\Anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
# ...

# %%
from sklearn import linear_model
classifierReg = linear_model.LinearRegression()
classifierReg.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-91355d8b0270> in <module>()
#       1 from sklearn import linear_model
#       2 classifierReg = linear_model.LinearRegression()
# ----> 3 classifierReg.fit(xtrain,ytrain)
#
# D:\Anaconda\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
from sklearn import linear_model
classifierReg = linear_model.Ridge(alpha = .5)
classifierReg.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-a267d5102d30> in <module>()
#       1 from sklearn import linear_model
#       2 classifierReg = linear_model.Ridge(alpha = .5)
# ----> 3 classifierReg.fit(xtrain,ytrain)
#
# D:\Anaconda\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     663         self : returns an instance of self.
#     664         """
# --> 665         return super(Ridge, self).fit(X, y, sample_weight=sample_weight)
#     666
#     667
#
# D:\Anaconda\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     481
#     482         X, y = check_X_y(X, y, ['csr', 'csc', 'coo'], dtype=_dtype,
# --> 483                          multi_output=True, y_numeric=True)
#     484
#     485         if ((sample_weight is not None) and
#
# ...

# %%
from sklearn import svm
classifierSVR = svm.SVR()
classifierSVR.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-5aaff4f5e4cc> in <module>()
#       1 from sklearn import svm
#       2 classifierSVR = svm.SVR()
# ----> 3 classifierSVR.fit(xtrain,ytrain)
#
# D:\Anaconda\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
